# %% [markdown]
# <a href="https://colab.research.google.com/github/liviasantos08/ETL-com-Python/blob/main/Transforma%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install panda
# Out:
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7255 sha256=e153ebbde1029d92a27881aaa5062d5ea77e93a9b6edbe374ffa0edcd4e8f010
#   Stored in directory: /root/.cache/pip/wheels/e6/3d/81/a3665ce657d35359ca337b1db2975dbe5cd281a88b8982f6b6
# Successfully built panda
# ...

# %%
pip install pandera
# Out:
# ...
#      |████████████████████████████████| 186 kB 28.1 MB/s
# ...
#      |████████████████████████████████| 161 kB 46.4 MB/s
# ...

# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes=['**','###!','####','****','*****','NULL']
df=pd.read_csv("/content/ocorrencia (1).csv", sep=";",dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
# 5              39807               39807  ...        17:53:00                   0
# 6              40215               40215  ...        18:40:00                   0
# 7              39707               39707  ...        12:30:00                   3
# 8              39156               39156  ...        23:15:00                   2
# 9              39711               39711  ...        20:00:00                   0
#
# [10 rows x 7 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
scheme = pa.DataFrameSchema(
        columns = {
          'codigo_ocorrencia':pa.Column(pa.Int),
          'codigo_ocorrencia2':pa.Column(pa.Int),
          'ocorrencia_classificacao':pa.Column(pa.String),
          'ocorrencia_cidade':pa.Column(pa.String),
          'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,4), nullable=True),
          'ocorrencia_aerodromo':pa.Column(pa.String, nullable=True),
          'ocorrencia_dia':pa.Column(pa.DateTime),
          'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),#trabalhando com expressão regular
          'total_recomendacoes':pa.Column(pa.Int)
       }
)

# %%
scheme.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-7-2825a947f404> in <module>()
# ----> 1 scheme.validate(df)
#
# /usr/local/lib/python3.7/dist-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     490             random_state=random_state,
#     491             lazy=lazy,
# --> 492             inplace=inplace,
#     493         )
#     494
#
# /usr/local/lib/python3.7/dist-packages/pandera/schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     604                         msg,
#     605                         failure_cases=scalar_failure_case(colname),
# --> 606                         check="column_in_dataframe",
#     607                     ),
#     608                 )
#
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia\tcodigo_ocorrencia1\tocorrencia_classificacao\tocorrencia_cidade\tocorrencia_uf\tocorrencia_aerodromo\tocorrencia_dia\tocorrencia_hora\ttotal_recomendacoes    object
# dtype: object

# %%
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 10              39789               39789  ...        21:30:00                   0
# 11              40069               40069  ...        14:50:00                   8
# 12              40414               40414  ...        03:00:00                   0
# 13              39507               39507  ...        17:00:00                   2
# 14              40107               40107  ...        14:30:00                   0
# 15              39315               39315  ...        21:22:00                   0
#
# [6 rows x 9 columns]

# %%
#Localização pelo indice
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 10              39789               39789  ...        21:30:00                   0
# 11              40069               40069  ...        14:50:00                   8
# 12              40414               40414  ...        03:00:00                   0
# 13              39507               39507  ...        17:00:00                   2
# 14              40107               40107  ...        14:30:00                   0
#
# [5 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#localiza o valor não disponivel na coluna ocorrencia_hora
filtro=df.ocorrencia_hora.isna()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4102              78823  ...                    0
#
# [1 rows x 9 columns]

# %%
#Ocorrencias com mais de 10 recomendações
filtro=df.total_recomendacoes>10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 63                39992  ...                   11
# 326               42250  ...                   19
# 530               43471  ...                   11
# 727               44377  ...                   11
# 872               44796  ...                   23
# 884               44888  ...                   11
# 1062              45554  ...                   20
# 1972              47938  ...                   11
# 2797              52265  ...                   13
# 3932              66432  ...                   12
#
# [10 rows x 7 columns]

# %%
#Ocorrencias com mais de 10 recomendações: Cidades
filtro=df.total_recomendacoes>10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
#Ocorrencias cuja classificação == INCIDENTE GRAVE
filtro=df.ocorrencia_classificacao=='INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade', 'ocorrencia_classificacao']]
# Out:
#      ocorrencia_cidade ocorrencia_classificacao
# 7             CANUTAMA          INCIDENTE GRAVE
# 8             CASCAVEL          INCIDENTE GRAVE
# 9        PARÁ DE MINAS          INCIDENTE GRAVE
# 29            CURITIBA          INCIDENTE GRAVE
# 35              PALMAS          INCIDENTE GRAVE
# ...                ...                      ...
# 6090             MARAÚ          INCIDENTE GRAVE
# 6095   ELDORADO DO SUL          INCIDENTE GRAVE
# 6097     CAXIAS DO SUL          INCIDENTE GRAVE
# 6098   CHAPADÃO DO SUL          INCIDENTE GRAVE
# 6104       VOTUPORANGA          INCIDENTE GRAVE
#
# [791 rows x 2 columns]

# %%
#Ocorrencias cuja classificação == INCIDENTE GRAVE e o estado de SP
filtro1=df.ocorrencia_classificacao=='INCIDENTE GRAVE'
filtro2=df.ocorrencia_cidade=='SÃO PAULO'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 219               41411  ...                    2
# 297               42289  ...                    0
# 380               42757  ...                    0
# 461               43459  ...                    0
# 1024              45553  ...                    5
# 1353              45867  ...                    0
# 2294              50093  ...                    0
# 2661              51417  ...                    0
# 2952              52779  ...                    0
# 2963              52840  ...                    0
# 3934              66444  ...                    1
# 4275              77281  ...                    0
# 4369              77694  ...                    0
# 4498              77921  ...                    0
# 4619              78171  ...                    0
# 4635              78203  ...                    0
# 4705              78332  ...                    0
# 5167              78998  ...                    0
# ...

# %%
#Ocorrencias cuja (classificação == INCIDENTE GRAVE ou classificaçao == INCIDENTE) e o estado == SÃO PAULO
filtro1=df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2=df.ocorrencia_cidade=='SÃO PAULO'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 16                39809  ...                    0
# 64                39386  ...                    0
# 77                40314  ...                    0
# 95                40329  ...                    0
# 134               40262  ...                    0
# ...                 ...  ...                  ...
# 6010              80151  ...                    0
# 6055              80174  ...                    0
# 6069              80192  ...                    0
# 6084              80234  ...                    0
# 6085              80208  ...                    0
#
# [263 rows x 7 columns]

# %%
#ocorrência cuja cidade comecem com a letra C
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 6                 40215  ...                    0
# 7                 39707  ...                    3
# 8                 39156  ...                    2
# 15                39315  ...                    0
# 20                40310  ...                    0
# ...                 ...  ...                  ...
# 6094              80225  ...                    0
# 6097              80231  ...                    0
# 6098              80248  ...                    0
# 6100              80235  ...                    0
# 6113              80259  ...                    0
#
# [895 rows x 7 columns]

# %%
#ocorrência cuja cidade terminam com a letra A
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 12                40414  ...                    0
# 15                39315  ...                    0
# 25                39772  ...                    0
# 26                39847  ...                    0
# ...                 ...  ...                  ...
# 6093              80227  ...                    0
# 6094              80225  ...                    0
# 6102              80240  ...                    0
# 6104              80238  ...                    0
# 6108              80244  ...                    0
#
# [1642 rows x 7 columns]

# %%
#ocorrência cuja cidade terminam com a letra MA
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 15                39315  ...                    0
# 408               43062  ...                    1
# 688               44198  ...                    0
# 1035              51785  ...                    0
# 1377              45939  ...                    0
# 1401              46180  ...                    0
# 2099              49113  ...                    4
# 2102              48799  ...                    0
# 2646              80059  ...                    0
# 2657              51347  ...                    0
# 2857              52340  ...                    1
# 2968              52832  ...                    0
# 2999              52979  ...                    0
# 3042              52984  ...                    0
# 3094              53596  ...                    0
# 3159              53223  ...                    0
# 3173              53265  ...                    2
# ...

# %%
#ocorrência cuja cidade contêm a letra MA
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 13                39507  ...                    2
# 15                39315  ...                    0
# 35                39487  ...                    0
# 78                39916  ...                    2
# ...                 ...  ...                  ...
# 6075              80205  ...                    0
# 6086              80212  ...                    0
# 6090              80221  ...                    0
# 6093              80227  ...                    0
# 6106              80249  ...                    0
#
# [514 rows x 7 columns]

# %%
df.tail()
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 6109              80245  ...                    0
# 6110              80247  ...                    0
# 6111              80251  ...                    0
# 6112              80257  ...                    0
# 6113              80259  ...                    0
#
# [5 rows x 7 columns]
